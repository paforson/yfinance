# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting appdirs==1.4.4
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: async-generator==1.10 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (1.10)
# Requirement already satisfied: attrs==20.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (20.3.0)
# Requirement already satisfied: backcall==0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: bleach==3.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: certifi==2020.11.8 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 6)) (2020.11.8)
# Requirement already satisfied: chardet==3.0.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 7)) (3.0.4)
# Requirement already satisfied: cycler==0.10.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 8)) (0.10.0)
# Requirement already satisfied: decorator==4.4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: defusedxml==0.6.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: dill==0.3.3 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 11)) (0.3.3)
# Collecting distlib==0.3.1
#   Downloading distlib-0.3.1-py2.py3-none-any.whl (335 kB)
# Requirement already satisfied: entrypoints==0.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 13)) (0.3)
# Collecting filelock==3.0.12
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: idna==2.10 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 15)) (2.10)
# Requirement already satisfied: importlib-metadata==3.3.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 16)) (3.3.0)
# Requirement already satisfied: ipykernel==5.4.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 17)) (5.4.2)
# Requirement already satisfied: ipython==7.19.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 18)) (7.19.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: ipywidgets==7.5.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 20)) (7.5.1)
# Requirement already satisfied: Jinja2==2.11.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 21)) (2.11.2)
# Requirement already satisfied: joblib==0.17.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 22)) (0.17.0)
# Requirement already satisfied: jsonschema==3.2.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 23)) (3.2.0)
# Requirement already satisfied: kiwisolver==1.3.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 24)) (1.3.1)
# Requirement already satisfied: MarkupSafe==1.1.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 25)) (1.1.1)
# Requirement already satisfied: matplotlib==3.3.3 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 26)) (3.3.3)
# Requirement already satisfied: mistune==0.8.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 27)) (0.8.4)
# Requirement already satisfied: nbclient==0.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 28)) (0.5.1)
# Requirement already satisfied: nbconvert==6.0.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 29)) (6.0.7)
# Requirement already satisfied: nbformat==5.0.8 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 30)) (5.0.8)
# Requirement already satisfied: nest-asyncio==1.4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 31)) (1.4.3)
# Requirement already satisfied: numpy==1.19.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 32)) (1.19.4)
# Requirement already satisfied: packaging==20.8 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 33)) (20.8)
# Requirement already satisfied: pandas==1.0.5 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 34)) (1.0.5)
# Requirement already satisfied: pandocfilters==1.4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 35)) (1.4.3)
# Requirement already satisfied: parso==0.7.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 36)) (0.7.1)
# Requirement already satisfied: pexpect==4.8.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 37)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 38)) (0.7.5)
# Requirement already satisfied: Pillow==8.0.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 39)) (8.0.1)
# Requirement already satisfied: pluggy==0.13.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 40)) (0.13.1)
# Requirement already satisfied: prometheus-client==0.9.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 41)) (0.9.0)
# Requirement already satisfied: prompt-toolkit==3.0.8 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 42)) (3.0.8)
# Requirement already satisfied: psycopg2-binary==2.8.6 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 43)) (2.8.6)
# Requirement already satisfied: ptyprocess==0.6.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 44)) (0.6.0)
# Requirement already satisfied: Pygments==2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 45)) (2.7.3)
# Requirement already satisfied: pyparsing==2.4.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 46)) (2.4.7)
# Requirement already satisfied: pyrsistent==0.17.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 47)) (0.17.3)
# Requirement already satisfied: python-dateutil==2.8.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 48)) (2.8.1)
# Requirement already satisfied: python-jsonrpc-server==0.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 49)) (0.4.0)
# Requirement already satisfied: python-language-server@ git+https://github.com/deepnote/python-language-server.git@626667573c1a7836c1e144790b5390feb7f3c111 from git+https://github.com/deepnote/python-language-server.git@626667573c1a7836c1e144790b5390feb7f3c111 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 50)) (0.5+1.g6266675)
# Requirement already satisfied: pytz==2020.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 51)) (2020.4)
# Requirement already satisfied: pyzmq==20.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 52)) (20.0.0)
# Requirement already satisfied: requests==2.25.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 53)) (2.25.0)
# Requirement already satisfied: scikit-learn==0.23.2 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 54)) (0.23.2)
# Requirement already satisfied: scipy==1.5.4 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 55)) (1.5.4)
# Requirement already satisfied: Send2Trash==1.5.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 56)) (1.5.0)
# Requirement already satisfied: six==1.15.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 57)) (1.15.0)
# Requirement already satisfied: terminado==0.9.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 58)) (0.9.1)
# Requirement already satisfied: testpath==0.4.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 59)) (0.4.4)
# Requirement already satisfied: threadpoolctl==2.1.0 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 60)) (2.1.0)
# Requirement already satisfied: tornado==6.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 61)) (6.1)
# Requirement already satisfied: traitlets==5.0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 62)) (5.0.5)
# Requirement already satisfied: typing-extensions==3.7.4.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 63)) (3.7.4.3)
# Requirement already satisfied: ujson==4.0.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 64)) (4.0.1)
# Requirement already satisfied: urllib3==1.26.2 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 65)) (1.26.2)
# Collecting virtualenv==20.1.0
#   Downloading virtualenv-20.1.0-py2.py3-none-any.whl (4.9 MB)
# Requirement already satisfied: wcwidth==0.2.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 67)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 68)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==3.5.1 in /opt/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 69)) (3.5.1)
# Requirement already satisfied: zipp==3.4.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from -r ./requirements.txt (line 70)) (3.4.0)
# Collecting yfinance
#   Downloading yfinance-0.1.55.tar.gz (23 kB)
# Collecting finvizfinance==0.7.3
#   Downloading finvizfinance-0.7.3-py3-none-any.whl (23 kB)
# Requirement already satisfied: jupyter-client in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel==5.4.2->-r ./requirements.txt (line 17)) (6.1.7)
# Requirement already satisfied: setuptools>=18.5 in /opt/venv/lib/python3.7/site-packages (from ipython==7.19.0->-r ./requirements.txt (line 18)) (50.3.2)
# Requirement already satisfied: jedi>=0.10 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython==7.19.0->-r ./requirements.txt (line 18)) (0.17.2)
# Requirement already satisfied: jupyterlab-pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->-r ./requirements.txt (line 29)) (0.1.2)
# Requirement already satisfied: jupyter-core in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from nbconvert==6.0.7->-r ./requirements.txt (line 29)) (4.7.0)
# Requirement already satisfied: notebook>=4.4.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from widgetsnbextension==3.5.1->-r ./requirements.txt (line 69)) (7.0.0.dev0)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.6.2-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
# Collecting datetime
#   Downloading DateTime-4.3-py2.py3-none-any.whl (60 kB)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting zope.interface
#   Downloading zope.interface-5.2.0-cp37-cp37m-manylinux2010_x86_64.whl (237 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2; python_version >= "3.0"
#   Downloading soupsieve-2.1-py3-none-any.whl (32 kB)
# Building wheels for collected packages: yfinance, multitasking, bs4
#   Building wheel for yfinance (setup.py): started
#   Building wheel for yfinance (setup.py): finished with status 'done'
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22618 sha256=f62fcebd76ed6ed152f1ab9e17b8a895559bec316c920fe4c68e324ddafacc6d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pfk7gswk/wheels/aa/8a/36/59ed4f6fbcb6100967618eeb0696046bf9777a41ac2ff1f9b9
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8367 sha256=7ea30d8575e6c9ecd7464cb632c14901b7667f1ad9c0cbc2a96a24cafbeeec5b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pfk7gswk/wheels/ae/25/47/4d68431a7ec1b6c4b5233365934b74c1d4e665bf5f968d363a
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=867a493dc1343bd01c0cbda9464a61d18a8467055631a2e9a26898e2ce5ea3bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pfk7gswk/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built yfinance multitasking bs4
# Installing collected packages: appdirs, distlib, filelock, virtualenv, multitasking, lxml, yfinance, zope.interface, datetime, soupsieve, beautifulsoup4, bs4, finvizfinance
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.9.3 bs4-0.0.1 datetime-4.3 distlib-0.3.1 filelock-3.0.12 finvizfinance-0.7.3 lxml-4.6.2 multitasking-0.0.9 soupsieve-2.1 virtualenv-20.1.0 yfinance-0.1.55 zope.interface-5.2.0
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# virtualenv 20.1.0 requires importlib-metadata<3,>=0.12; python_version < "3.8", but you'll have importlib-metadata 3.3.0 which is incompatible.
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.
